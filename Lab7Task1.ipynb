# %% [markdown]
# - Variables are A, B, C, D, E
# - Domains are 1-6

# %%
variables = ['A', 'B', 'C', 'D', 'E']

neighbors = {
  'A': variables,
  'B': variables.remove('B'),
  'C': variables,
  'D': variables.remove('D'),
  'E': variables.remove('E'),
}

neighbors
# Out:
# {'A': ['A', 'C'], 'B': None, 'C': ['A', 'C'], 'D': None, 'E': None}

# %%
from src.algorithms import minimax_search
from src.gameClass import play_game
from src.FiveMiseryGameClass import FiveMisery
from src.players import smart_player,random_player, human_player

# %% [markdown]
# ## Smart Player X vs Random Player O

# %%
gameresult=play_game(FiveMisery(), dict(X=smart_player(minimax_search), O=random_player), verbose=True).utility
gameresult
# Out:
# Player X move: 3
# state ((4, 'O'))
#
# Player O move: 1
# state ((5, 'X'))
# 1

# %% [markdown]
# ## Human Player X vs Smart Player O

# %%
gameresult=play_game(FiveMisery(), dict(X=human_player, O=smart_player(minimax_search)), verbose=True).utility
gameresult
# Out:
# Player X move: 3
# state ((4, 'O'))
#
# Player O move: 1
# state ((5, 'X'))
# 1
